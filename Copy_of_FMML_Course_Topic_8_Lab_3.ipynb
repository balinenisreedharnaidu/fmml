# %% [markdown]
# <a href="https://colab.research.google.com/github/BODDUSRIPAVAN/FMML_Project_and_Labs/blob/main/Copy_of_FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-28 14:40:01--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   124MB/s    in 0.6s
#
# 2023-05-28 14:40:02 (124 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 27487  1703.08516v1  Quantitative extraction of high-dimensional mi...    cs
# 18026  cs/0202025v1  A vast and interesting family of natural seman...    cs
# 19268   1304.2750v1  Our previous work on classifying complex ship ...    cs
# 33488   1401.5221v1  One of the disadvantages in Connection of wind...    cs
# 36785   1411.2800v2  Abstract argumentation framework (\AFname) is ...    cs
# ...             ...                                                ...   ...
# 23015  1802.00045v1  Gaussian process (GP) models provide a powerfu...  stat
# 22389  1605.05697v1  We study the problem of estimating the paramet...  stat
# 22227  1509.02357v1  We study in this paper the consequences of usi...  stat
# 31664  cs/0009007v1  In real-world environments it usually is diffi...    cs
# 11940  1704.06803v1  Matrix completion models are among the most co...    cs
#
#                                                    title  year  \
# 27487  Radiomics strategies for risk assessment of tu...  2017
# 18026             Distance Semantics for Belief Revision  2002
# 19268  Implementing a Bayesian Scheme for Revising Be...  2013
# 33488  Optimal Intelligent Control for Wind Turbulenc...  2014
# 36785  Exploiting Parallelism for Hard Problems in Ab...  2014
# ...                                                  ...   ...
# 23015  Composite Gaussian Processes: Scalable Computa...  2018
# 22389  Online Algorithms For Parameter Mean And Varia...  2016
# 22227  Empirical risk minimization is consistent with...  2015
# 31664   Robust Classification for Imprecise Environments  2000
# 11940  Geometric Matrix Completion with Recurrent Mul...  2017
#
#                                                 keywords
# 27487  [quantitative, extraction, dimensional, radiom...
# 18026  [interesting, semantics, characterized, ration...
# 19268  [classifying, classification, uncertainty, ass...
# 33488  [disadvantages, connection, conversion, transm...
# 36785  [argumentation, framework, framework, encompas...
# ...                                                  ...
# 23015  [prediction, computationally, prohibitive, sce...
# 22389  [estimating, parameters, regression, observati...
# 22227  [consequences, percentage, regression, equival...
# 31664  [environments, difficult, operating, condition...
# 11940  [completion, formulations, recommender, perfor...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 27487    [quantitative, extraction, dimensional, radiom...
# 18026    [interesting, semantics, characterized, ration...
# 19268    [classifying, classification, uncertainty, ass...
# 33488    [disadvantages, connection, conversion, transm...
# 36785    [argumentation, framework, framework, encompas...
#                                ...
# 6096     [computing, laplacian, application, clustering...
# 13591    [memristors, gathering, techniques, environmen...
# 8508     [framework, marginalized, adaptation, addressi...
# 22788    [variables, probabilistic, automatically, stoc...
# 12444    [hurricanes, circulating, originating, subtrop...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8823 words.
# Out of those 4583 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="bd894bb5-1a37-4ce1-b9e5-c8fb2cc96879" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bd894bb5-1a37-4ce1-b9e5-c8fb2cc96879")) {                    Plotly.newPlot(                        "bd894bb5-1a37-4ce1-b9e5-c8fb2cc96879",                        [{"x":["imbalance","strategies","furthermore","essential","extraction","radiomics","treatments","demonstrated","personalization","independent","assessing","intensity","heterogeneity","performance","potential","radiation","extracted","quantification","constructed","dimensional","treatment","adjustment","validation","different","prediction","variables","combining","quantitative","stratification","prognostic","assessment","metastases","important","rationality","postulates","properties","semantics","characterized","interesting","revisions","techniques","associated","computing","classifying","requirements","efficient","straightforward","classification","hypothesis","analytical","instantiation","explanations","requirement","procedure","commitment","implementation","available","difficult","addresses","optimization","qualitative","uncertainty","commitments","implementing","maintenance","practical","widespread","generally","efficiency","regulation","therefore","artificial","turbulence","controlled","conversion","transmission","operation","consequently","regulated","perceptron","rejection","disadvantages","approaches","plentiful","increasingly","connection","successfully","disturbance","intelligent","encompass","extensions","significant","technical","programming","definition","parallelism","algorithm","recursive","reasoning","exploiting","enumerating","improvements","frameworks","computational","solutions","enumeration","potentially","framework","nonmonotonic","argumentation","computation","preferred","algorithms","orthogonality","establish","multiplicative","factorization","clustering","nonlinear","structure","intrinsic","equivalence","theoretical","orthogonal","essentially","geometric","regularization","normalized","considerably","introduce","influenced","specifically","coefficients","criterion","experiments","corresponding","highlight","resolution","determine","distribution","identical","photography","adaptively","reflection","projection","component","deviating","achieving","diversity","applicability","respectively","importance","challenging","illumination","subspaces","calculation","application","operators","crossover","determining","including","technique","processes","modelling","predictive","representation","appropriate","incomplete","industrial","selection","describes","anticipate","decreasing","traditional","significantly","classical","distinguish","scientific","additionally","initiatives","understand","occurrence","comprehensive","robustness","predicting","attrition","regression","challenge","probability","regressions","censoring","ensembles","information","predicted","predictions","industries","statistical","retention","systematically","conventional"],"y":[9,95,166,75,130,2,5,107,8,132,14,28,7,863,154,5,107,16,57,181,31,9,44,730,235,145,102,49,3,5,41,2,356,8,5,200,97,28,53,2,395,114,148,38,50,389,30,477,57,27,4,17,34,123,4,132,332,156,54,347,58,84,3,24,5,145,15,74,177,2,144,145,2,31,18,15,44,38,5,20,6,8,422,3,49,36,76,2,67,5,34,259,45,106,46,14,838,32,136,77,6,114,24,303,153,4,47,549,9,8,153,21,636,3,55,19,37,141,59,329,37,21,156,29,33,64,86,22,26,334,10,152,39,44,607,129,31,111,65,227,15,7,32,8,56,101,2,74,41,45,87,82,288,38,15,19,265,49,10,36,226,241,99,57,57,402,84,42,21,143,106,6,16,178,275,109,29,27,63,4,66,32,60,107,96,1,104,137,174,2,1,13,709,40,82,3,151,2,21,103],"type":"bar"},{"x":["imbalance","strategies","furthermore","essential","extraction","radiomics","treatments","demonstrate ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4583,), (4583, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8191666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.33333333333333337);'>Hellinger</span> <span style=''>Distance</span> <span style=''>Trees</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Imbalanced</span> <span style=''>Streams</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Classifiers</span> <span style=''>trained</span> <span style=''>on</span> <span style=''>data</span> <span style=''>sets</span> <span style='background-color:rgba(0, 255, 0, 0.5);'>possessing</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>imbalanced</span> <span style=''>class</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>are</span> <span style=''>known</span> <span style=''>to</span> <span style=''>exhibit</span> <span style=''>poor</span> <span style='background-color:rgba(0, 255, 0, 0.4285714285714285);'>generalisation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>This</span> <span style=''>is</span> <span style=''>known</span> <span style=''>as</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>imbalanced</span> <span style=''>learning</span> <span style=''>problem</span> <span style=''>The</span> <span style=''>problem</span> <span style=''>becomes</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particularly</span> <span style=''>acute</span> <span style=''>when</span> <span style=''>we</span> <span style=''>consider</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>incremental</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classifiers</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>operating</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>imbalanced</span> <span style=''>data</span> <span style=''>streams</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>especially</span> <span style=''>when</span> <span style=''>the</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>objective</span> <span style=''>is</span> <span style=''>rare</span> <span style=''>class</span> <span style='background-color:rgba(0, 255, 0, 0.38011695906432746);'>identification</span> <span style=''>As</span> <span style=''>accuracy</span> <span style=''>may</span> <span style=''>provide</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>misleading</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>impression</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>imbalanced</span> <span style=''>data</span> <span style=''>existing</span> <span style=''>stream</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classifiers</span> <span style=''>based</span> <span style=''>on</span> <span style=''>accuracy</span> <span style=''>can</span> <span style=''>suffer</span> <span style=''>poor</span> <span style=''>minority</span> <span style=''>class</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>imbalanced</span> <span style=''>streams</span> <span style=''>with</span> <span style=''>the</span> <span style=''>result</span> <span style=''>being</span> <span style=''>low</span> <span style=''>minority</span> <span style=''>class</span> <span style=''>recall</span> <span style=''>rates</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>address</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>deficiency</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>proposing</span> <span style=''>the</span> <span style=''>u ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>An</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style=''>k</span> <span style=''>means</span> <span style=''>type</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>datasets</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incomplete</span> <span style=''>records</span> <br/><br/><span style=''>The</span> <span style=''>k</span> <span style=''>means</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>is</span> <span style=''>the</span> <span style=''>most</span> <span style=''>popular</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonparametric</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>method</span> <span style=''>in</span> <span style=''>use</span> <span style=''>but</span> <span style=''>cannot</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generally</span> <span style=''>be</span> <span style=''>applied</span> <span style=''>to</span> <span style=''>data</span> <span style=''>sets</span> <span style=''>with</span> <span style=''>missing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observations</span> <span style=''>The</span> <span style=''>usual</span> <span style=''>practice</span> <span style=''>with</span> <span style=''>such</span> <span style=''>data</span> <span style=''>sets</span> <span style=''>is</span> <span style=''>to</span> <span style=''>either</span> <span style=''>impute</span> <span style=''>the</span> <span style=''>values</span> <span style=''>under</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumption</span> <span style=''>of</span> <span style=''>a</span> <span style=''>missing</span> <span style=''>at</span> <span style=''>random</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>mechanism</span> <span style=''>or</span> <span style=''>to</span> <span style=''>ignore</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incomplete</span> <span style=''>records</span> <span style=''>and</span> <span style=''>then</span> <span style=''>to</span> <span style=''>use</span> <span style=''>the</span> <span style=''>desired</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>method</span> <span style=''>We</span> <span style=''>develop</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style=''>version</span> <span style=''>of</span> <span style=''>the</span> <span style=''>k</span> <span style=''>means</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>that</span> <span style=''>allows</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>cases</span> <span style=''>where</span> <span style=''>not</span> <span style=''>all</span> <span style=''>the</span> <span style=''>features</span> <span style=''>have</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observations</span> <span style=''>recorded</span> <span style=''>Our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extension</span> <span style=''>is</span> <span style=''>called</span> <span style=''>k</span> <span style=''>m</span> <span style=''>means</span> <span style=''>and</span> <span style=''>reduces</span> <span style=''>to</span> <span style=''>the</span> <span style=''>k</span> <span style=''>means</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>when</span> <span style=''>all</span> <span style=''>records</span> <span style=''>are</span> <span style=''>complete</span> <span style=''>We</span> <span style=''>also</span> <span style=''>provide ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Smoothing</span> <span style=''>Proximal</span> <span style=''>Gradient</span> <span style=''>Method</span> <span style=''>for</span> <span style=''>General</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Structured</span> <span style=''>Sparse</span> <span style=''>Learning</span> <br/><br/><span style=''>We</span> <span style=''>study</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>learning</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.37586206896551716);'>dimensional</span> <span style='background-color:rgba(255, 0, 0, 0.5555555555555556);'>regression</span> <span style=''>models</span> <span style='background-color:rgba(255, 0, 0, 0.4380165289256199);'>regularized</span> <span style=''>by</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structured</span> <span style=''>sparsity</span> <span style=''>inducing</span> <span style=''>penalty</span> <span style=''>that</span> <span style=''>encodes</span> <span style=''>prior</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structural</span> <span style='background-color:rgba(0, 255, 0, 0.31296296296296294);'>information</span> <span style=''>on</span> <span style=''>either</span> <span style=''>input</span> <span style=''>or</span> <span style=''>output</span> <span style=''>sides</span> <span style=''>We</span> <span style=''>consider</span> <span style=''>two</span> <span style=''>widely</span> <span style=''>adopted</span> <span style=''>types</span> <span style=''>of</span> <span style=''>such</span> <span style='background-color:rgba(255, 0, 0, 0.47826086956521735);'>penalties</span> <span style=''>as</span> <span style=''>our</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333337);'>motivating</span> <span style=''>examples</span> <span style=''>1)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>overlapping</span> <span style=''>group</span> <span style=''>lasso</span> <span style=''>penalty</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style=''>l1l2</span> <span style=''>mixed</span> <span style=''>norm</span> <span style=''>penalty</span> <span style=''>and</span> <span style=''>2)</span> <span style=''>graph</span> <span style=''>guided</span> <span style=''>fusion</span> <span style=''>penalty</span> <span style=''>For</span> <span style=''>both</span> <span style=''>types</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.47826086956521735);'>penalties</span> <span style=''>due</span> <span style=''>to</span> <span style=''>their</span> <span style=''>non</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>separability</span> <span style='background-color:rgba(0, 255, 0, 0.4022988505747127);'>developing</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>method</span> <span style=''>has</span> <span style=''>remained</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.4922279792746115);'>challenging</span> <span style=''>problem</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>general</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>approach</span> <span style=''>called</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>smoothing</span> <span style=''>proximal</span> <span style=''>gradient</span> <span style=''>method</span> <span style=''>which</span> <span style=''>can</span> <span style=''>solve</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structured</span> <span styl ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>Flexible</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Efficient</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Algorithmic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Framework</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Constrained</span> <span style=''>Matrix</span> <span style=''>and</span> <span style=''>Tensor</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Factorization</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>general</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithmic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constrained</span> <span style=''>matrix</span> <span style=''>and</span> <span style=''>tensor</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>factorization</span> <span style=''>which</span> <span style=''>is</span> <span style=''>widely</span> <span style=''>used</span> <span style=''>in</span> <span style=''>signal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processing</span> <span style=''>and</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>The</span> <span style=''>new</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>is</span> <span style=''>a</span> <span style=''>hybrid</span> <span style=''>between</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>alternating</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>(AO)</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>alternating</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>direction</span> <span style=''>method</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multipliers</span> <span style=''>(ADMM)</span> <span style=''>each</span> <span style=''>matrix</span> <span style=''>factor</span> <span style=''>is</span> <span style=''>updated</span> <span style=''>in</span> <span style=''>turn</span> <span style=''>using</span> <span style=''>ADMM</span> <span style=''>hence</span> <span style=''>the</span> <span style=''>name</span> <span style=''>AO</span> <span style=''>ADMM</span> <span style=''>This</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>combination</span> <span style=''>can</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>naturally</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>accommodate</span> <span style=''>a</span> <span style=''>great</span> <span style=''>variety</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constraints</span> <span style=''>on</span> <span style=''>the</span> <span style=''>factor</span> <span style=''>matrices</span> <span style=''>and</span> <span style=''>almost</span> <span style=''>all</span> <span style=''>possible</span> <span style=''>loss</span> <span style=''>measures</span> <span style=''>for</span> <span style=''>the</span> <span style=''>fitting</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Computation</span> <span style=''>caching</span> <span style=''>and</span> <span style=''>warm</span> <span style=''>start</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>strategies</span> <span style=''>are</span> <span style=''>used</span> <span style=''>to</span> <span style=''>ensure</span> <span style=''>that</span> <span style=''>each</span> <span style=''>update</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evaluated</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficiently</span> <span style=''>while</span> <span style=''>the</span> <span st ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	processing (0.10696517412935323)
# 	challenging (0.1023454157782516)
# 	segmentation (0.06680881307746979)
# 	architecture (0.0867093105899076)
# 	representation (0.14285714285714285)
# 	information (0.251954513148543)
# 	experimental (0.1396588486140725)
# 	different (0.2594171997157072)
# 	convolutional (0.12544420753375976)
# 	recognition (0.13255152807391613)
#
# Some Statistics words are:
# 	variables (0.13695871097683787)
# 	distribution (0.1732124874118832)
# 	stochastic (0.14249748237663645)
# 	theoretical (0.1555891238670695)
# 	algorithm (0.4003021148036254)
# 	statistical (0.16163141993957703)
# 	estimation (0.18429003021148035)
# 	inference (0.19889224572004027)
# 	dimensional (0.20090634441087613)
# 	regression (0.18328298086606243)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="d1a68071-4cb0-413a-adc3-ff7e6174d3aa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d1a68071-4cb0-413a-adc3-ff7e6174d3aa")) {                    Plotly.newPlot(                        "d1a68071-4cb0-413a-adc3-ff7e6174d3aa",                        [{"x":["imbalance","strategies","furthermore","essential","extraction","radiomics","treatments","demonstrated","personalization","independent","assessing","intensity","heterogeneity","performance","potential","radiation","extracted","quantification","constructed","dimensional","treatment","adjustment","validation","different","prediction","variables","combining","quantitative","stratification","prognostic","assessment","metastases","important","rationality","postulates","properties","semantics","characterized","interesting","revisions","techniques","associated","computing","classifying","requirements","efficient","straightforward","classification","hypothesis","analytical","instantiation","explanations","requirement","procedure","commitment","implementation","available","difficult","addresses","optimization","qualitative","uncertainty","commitments","implementing","maintenance","practical","widespread","generally","efficiency","regulation","therefore","artificial","turbulence","controlled","conversion","transmission","operation","consequently","regulated","perceptron","rejection","disadvantages","approaches","plentiful","increasingly","connection","successfully","disturbance","intelligent","encompass","extensions","significant","technical","programming","definition","parallelism","algorithm","recursive","reasoning","exploiting","enumerating","improvements","frameworks","computational","solutions","enumeration","potentially","framework","nonmonotonic","argumentation","computation","preferred","algorithms","orthogonality","establish","multiplicative","factorization","clustering","nonlinear","structure","intrinsic","equivalence","theoretical","orthogonal","essentially","geometric","regularization","normalized","considerably","introduce","influenced","specifically","coefficients","criterion","experiments","corresponding","highlight","resolution","determine","distribution","identical","photography","adaptively","reflection","projection","component","deviating","achieving","diversity","applicability","respectively","importance","challenging","illumination","subspaces","calculation","application","operators","crossover","determining","including","technique","processes","modelling","predictive","representation","appropriate","incomplete","industrial","selection","describes","anticipate","decreasing","traditional","significantly","classical","distinguish","scientific","additionally","initiatives","understand","occurrence","comprehensive","robustness","predicting","attrition","regression","challenge","probability","regressions","censoring","ensembles","information","predicted","predictions","industries","statistical","retention","systematically","conventional","explicitly","distances","comparisons","descriptor","consistency","descriptors","similarities","repetitive","progressive","confident","orientation","stability","bidirectional","appearance","experimental","unmatched","viewpoint","correspondences","formulated","candidates","candidate","progressively","comprises","routinely","increasing","considered","unlabeled","resamples","benchmark","bootstrap","intuitive","increased","positives","improvement","classifiers","supervised","simulations","instances","explanation","mechanics","synthetic","pretraining","generation","classifies","segmentation","extracting","multimodal","structures","underlying","architecture","documents","convolutional","annotators","demonstrate","correctly","localization","interpreta ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	resamples
# 	heteroscedasticity
# 	unavoidably
# 	procrustes
# 	hyperpriors
# 	presupposes
# 	seasonality
# 	incrementalonline
# 	isometric
# 	pretreatment
# 	semiparametric
# 	nonparametrically
# 	statistician
# 	periodicity
# 	volatility
# 	logarithmically
# 	missingness
# 	unnecessarily
# 	ingenious
# 	electroencephalography
# Some words which never appear in Statistics papers:
# 	radiomics
# 	metastases
# 	postulates
# 	revisions
# 	commitment
# 	commitments
# 	turbulence
# 	regulated
# 	disturbance
# 	enumerating
# 	nonmonotonic
# 	argumentation
# 	photography
# 	reflection
# 	deviating
# 	illumination
# 	repetitive
# 	progressive
# 	unmatched
# 	correspondences

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.055954527396632e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7725
